# %% [markdown]
# # Stream Q($\lambda$) algorithm with Atari envrionments:

# %% [markdown]
# The following code is distributed under the Creative Commons Attribution-NonCommercial 4.0. License See this [link](https://creativecommons.org/licenses/by-nc/4.0/deed.en) for more information.

# %% [markdown]
# ### 1. Install necessary packages:

# %%
# !pip install gymnasium==0.29.1
# !pip install numpy==1.26.4
# !pip install torch==2.3.0
# !pip install stable_baselines3==2.3.1
# !pip install "gymnasium[atari, accept-rom-license]"
# !pip install atari-py
# !apt-get install -y python3-opengl xvfb ffmpeg
# !pip install pyvirtualdisplay imageio

# %% [markdown]
# ### 2. Import necessary libraries:

# %%
import torch, math
import numpy as np
import gymnasium as gym
import os, pickle, argparse
import torch.nn as nn
from stable_baselines3.common.atari_wrappers import (
    EpisodicLifeEnv,
    FireResetEnv,
    MaxAndSkipEnv,
    NoopResetEnv,
)
import torch.nn.functional as F

# %% [markdown]
# ### 3. Implement the ObGD optimizer:

# %%
class ObGD(torch.optim.Optimizer):
    def __init__(self, params, lr=1.0, gamma=0.99, lamda=0.8, kappa=2.0):
        # 初始化优化器的参数
        defaults = dict(lr=lr, gamma=gamma, lamda=lamda, kappa=kappa)
        super(ObGD, self).__init__(params, defaults)

    def step(self, delta, reset=False):
        z_sum = 0.0  # 初始化 z_sum，用于累加所有参数的资格迹

        # 遍历每个参数组
        for group in self.param_groups:
            # 遍历每个参数
            for p in group["params"]:
                state = self.state[p]  # 获取当前参数的状态
                if len(state) == 0:
                    # 如果状态为空，初始化资格迹
                    state["eligibility_trace"] = torch.zeros_like(p.data)
                e = state["eligibility_trace"]  # 获取资格迹
                # 更新资格迹
                e.mul_(group["gamma"] * group["lamda"]).add_(p.grad, alpha=1.0)
                z_sum += e.abs().sum().item()  # 累加资格迹的绝对值之和

        delta_bar = max(abs(delta), 1.0)  # 计算 delta_bar，确保至少为 1.0
        dot_product = delta_bar * z_sum * group["lr"] * group["kappa"]  # 计算点积

        # 根据点积计算步长
        if dot_product > 1:
            step_size = group["lr"] / dot_product
        else:
            step_size = group["lr"]

        # 再次遍历每个参数组
        for group in self.param_groups:
            for p in group["params"]:
                state = self.state[p]  # 获取当前参数的状态
                e = state["eligibility_trace"]  # 获取资格迹
                # 更新参数
                p.data.add_(delta * e, alpha=-step_size)
                if reset:
                    e.zero_()  # 如果需要重置，清空资格迹

# %% [markdown]
# ### 4. Implement sparse initialization:

# %%
def sparse_init(tensor, sparsity, type='uniform'):

    if tensor.ndimension() == 2:
        fan_out, fan_in = tensor.shape

        num_zeros = int(math.ceil(sparsity * fan_in))

        with torch.no_grad():
            if type == 'uniform':
                tensor.uniform_(-math.sqrt(1.0 / fan_in), math.sqrt(1.0 / fan_in))
            elif type == 'normal':
                tensor.normal_(0, math.sqrt(1.0 / fan_in))
            else:
                raise ValueError("Unknown initialization type")
            for col_idx in range(fan_out):
                row_indices = torch.randperm(fan_in)
                zero_indices = row_indices[:num_zeros]
                tensor[col_idx, zero_indices] = 0
        return tensor

    elif tensor.ndimension() == 4:
        channels_out, channels_in, h, w = tensor.shape
        fan_in, fan_out = channels_in*h*w, channels_out*h*w

        num_zeros = int(math.ceil(sparsity * fan_in))

        with torch.no_grad():
            if type == 'uniform':
                tensor.uniform_(-math.sqrt(1.0 / fan_in), math.sqrt(1.0 / fan_in))
            elif type == 'normal':
                tensor.normal_(0, math.sqrt(1.0 / fan_in))
            else:
                raise ValueError("Unknown initialization type")
            for out_channel_idx in range(channels_out):
                indices = torch.randperm(fan_in)
                zero_indices = indices[:num_zeros]
                tensor[out_channel_idx].reshape(channels_in*h*w)[zero_indices] = 0
        return tensor
    else:
        raise ValueError("Only tensors with 2 or 4 dimensions are supported")

# %% [markdown]
# ### 5. Implement observation normalization and reward scaling:

# %%
import numpy as np


class SampleMeanStd:
    def __init__(self, shape=()):
        # 初始化均值、方差、计数和p值
        self.mean = np.zeros(shape, "float64")   # 均值初始化为0
        self.var = np.ones(shape, "float64")     # 方差初始化为1
        self.p = np.ones(shape, "float64")       # 用于计算方差的p值
        self.count = 0                           # 样本计数

    def update(self, x):
        # 更新均值和方差
        if self.count == 0:
            self.mean = x  # 第一个样本直接赋值为均值
            self.p = np.zeros_like(x)  # p值初始化为0
        # 使用从矩估计中得到的均值和方差更新公式
        self.mean, self.var, self.p, self.count = self.update_mean_var_count_from_moments(self.mean, self.p, self.count, x * 1.0)

    def update_mean_var_count_from_moments(self, mean, p, count, sample):
        # 计算新的均值、方差和计数
        new_count = count + 1  # 样本数量增加
        new_mean = mean + (sample - mean) / new_count  # 更新均值
        p = p + (sample - mean) * (sample - new_mean)  # 更新p值
        new_var = 1 if new_count < 2 else p / (new_count - 1)  # 更新方差
        return new_mean, new_var, p, new_count  # 返回更新后的均值、方差、p值和计数


class NormalizeObservation(gym.Wrapper, gym.utils.RecordConstructorArgs):
    def __init__(self, env: gym.Env, epsilon: float = 1e-8):
        # 初始化观察归一化包装器
        gym.utils.RecordConstructorArgs.__init__(self, epsilon=epsilon)
        gym.Wrapper.__init__(self, env)
        try:
            # 检查环境是否为向量环境
            self.num_envs = self.get_wrapper_attr("num_envs")
            self.is_vector_env = self.get_wrapper_attr("is_vector_env")
        except AttributeError:
            self.num_envs = 1  # 单环境
            self.is_vector_env = False  # 非向量环境

        # 根据环境类型初始化观察统计
        if self.is_vector_env:
            self.obs_stats = SampleMeanStd(shape=self.single_observation_space.shape)  # 向量环境
        else:
            self.obs_stats = SampleMeanStd(shape=self.observation_space.shape)  # 单环境
        self.epsilon = epsilon  # 防止除零的常数

    def step(self, action):
        # 执行动作并获取反馈
        obs, rews, terminateds, truncateds, infos = self.env.step(action)
        if self.is_vector_env:
            obs = self.normalize(obs)  # 归一化观察
        else:
            obs = self.normalize(np.array([obs]))[0]  # 单环境归一化
        return obs, rews, terminateds, truncateds, infos  # 返回观察、奖励等信息

    def reset(self, **kwargs):
        # 重置环境并归一化初始观察
        obs, info = self.env.reset(**kwargs)
        if self.is_vector_env:
            return self.normalize(obs), info  # 向量环境
        else:
            return self.normalize(np.array([obs]))[0], info  # 单环境

    def normalize(self, obs):
        # 归一化观察
        self.obs_stats.update(obs)  # 更新观察统计
        return (obs - self.obs_stats.mean) / np.sqrt(self.obs_stats.var + self.epsilon)  # 返回归一化结果


class ScaleReward(gym.core.Wrapper, gym.utils.RecordConstructorArgs):
    def __init__(self, env: gym.Env, gamma: float = 0.99, epsilon: float = 1e-8):
        # 初始化奖励缩放包装器
        gym.utils.RecordConstructorArgs.__init__(self, gamma=gamma, epsilon=epsilon)
        gym.Wrapper.__init__(self, env)
        try:
            # 检查环境是否为向量环境
            self.num_envs = self.get_wrapper_attr("num_envs")
            self.is_vector_env = self.get_wrapper_attr("is_vector_env")
        except AttributeError:
            self.num_envs = 1  # 单环境
            self.is_vector_env = False  # 非向量环境
        self.reward_stats = SampleMeanStd(shape=())  # 奖励统计
        self.reward_trace = np.zeros(self.num_envs)  # 奖励跟踪
        self.gamma = gamma  # 折扣因子
        self.epsilon = epsilon  # 防止除零的常数

    def step(self, action):
        # 执行动作并获取反馈
        obs, rews, terminateds, truncateds, infos = self.env.step(action)
        if not self.is_vector_env:
            rews = np.array([rews])  # 单环境奖励
        term = terminateds or truncateds  # 检查是否终止
        # 更新奖励跟踪
        self.reward_trace = self.reward_trace * self.gamma * (1 - term) + rews
        rews = self.normalize(rews)  # 归一化奖励
        if not self.is_vector_env:
            rews = rews[0]  # 单环境返回奖励
        return obs, rews, terminateds, truncateds, infos  # 返回观察、奖励等信息

    def normalize(self, rews):
        # 归一化奖励
        self.reward_stats.update(self.reward_trace)  # 更新奖励统计
        return rews / np.sqrt(self.reward_stats.var + self.epsilon)  # 返回归一化结果

# %% [markdown]
# ### 6. Implement the Stream Q($\lambda$) agent:

# %%
def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

class LayerNormalization(nn.Module):
    def __init__(self):
        super().__init__()
    def forward(self, input):
        return F.layer_norm(input, input.size())
    def extra_repr(self) -> str:
        return "Layer Normalization"

def initialize_weights(m):
    if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
        sparse_init(m.weight, sparsity=0.9)
        m.bias.data.fill_(0.0)

class StreamQ(nn.Module):
    def __init__(self, n_actions=3, hidden_size=256, lr=1.0, epsilon_target=0.01, epsilon_start=1.0, exploration_fraction=0.1, total_steps=1_000_000, gamma=0.99, lamda=0.8, kappa_value=2.0):
        super(StreamQ, self).__init__()
        self.n_actions = n_actions
        self.gamma = gamma
        self.epsilon_start = epsilon_start
        self.epsilon_target = epsilon_target
        self.epsilon = epsilon_start
        self.exploration_fraction = exploration_fraction
        self.total_steps = total_steps
        self.time_step = 0
        self.network = nn.Sequential(
            nn.Conv2d(4, 32, 8, stride=5),
            LayerNormalization(),
            nn.LeakyReLU(),
            nn.Conv2d(32, 64, 4, stride=3),
            LayerNormalization(),
            nn.LeakyReLU(),
            nn.Conv2d(64, 64, 3, stride=2),
            LayerNormalization(),
            nn.LeakyReLU(),
            nn.Flatten(start_dim=0),
            nn.Linear(256, hidden_size),
            LayerNormalization(),
            nn.LeakyReLU(),
            nn.Linear(hidden_size, n_actions)
        )
        self.apply(initialize_weights)
        self.optimizer = ObGD(list(self.parameters()), lr=lr, gamma=gamma, lamda=lamda, kappa=kappa_value)

    def q(self, x):
        x = torch.tensor(np.array(x), dtype=torch.float)
        return self.network(x)

    def sample_action(self, s):
        self.time_step += 1
        self.epsilon = linear_schedule(self.epsilon_start, self.epsilon_target, self.exploration_fraction * self.total_steps, self.time_step)
        if isinstance(s, np.ndarray):
            s = torch.tensor(np.array(s), dtype=torch.float)
        if np.random.rand() < self.epsilon:
            q_values = self.q(s)
            greedy_action = torch.argmax(q_values, dim=-1).item()
            random_action = np.random.randint(0, self.n_actions)
            if greedy_action == random_action:
                return random_action, False
            else:
                return random_action, True
        else:
            q_values = self.q(s)
            return torch.argmax(q_values, dim=-1), False

    def update_params(self, s, a, r, s_prime, done, is_nongreedy, overshooting_info=False):
        done_mask = 0 if done else 1
        s, a, r, s_prime, done_mask = torch.tensor(np.array(s), dtype=torch.float), \
                                        torch.tensor([a], dtype=torch.int).squeeze(0), \
                                        torch.tensor(np.array(r)), \
                                        torch.tensor(np.array(s_prime), dtype=torch.float), \
                                        torch.tensor(np.array(done_mask), dtype=torch.float)

        q_sa = self.q(s)[a]
        max_q_s_prime_a_prime = torch.max(self.q(s_prime), dim=-1).values
        td_target = r + self.gamma * max_q_s_prime_a_prime * done_mask
        delta = td_target - q_sa

        q_output = -q_sa
        self.optimizer.zero_grad()
        q_output.backward()
        self.optimizer.step(delta.item(), reset=(done or is_nongreedy))

# %% [markdown]
# ### 7. Define agent-enviroment interaction loop:

# %%
def agent_env_interaction(env_name='PongNoFrameskip-v4', seed=0, lr=1.0, gamma=0.99, lamda=0.8, total_steps=10_000, epsilon_target=0.01, epsilon_start=1.0, exploration_fraction=0.05, kappa_value=2.0, debug=True, save_agent=True, update_agent=True, load_agent=None, render=False):
    # 设置随机种子
    torch.manual_seed(seed); np.random.seed(seed)

    # 创建环境并进行预处理
    env = gym.make(env_name, render_mode="rgb_array")
    env = gym.wrappers.RecordEpisodeStatistics(env)  # 记录每个回合的统计信息
    env = NoopResetEnv(env, noop_max=30)  # 随机执行一些无效动作
    env = MaxAndSkipEnv(env, skip=4)  # 每隔4帧执行一次动作
    env = EpisodicLifeEnv(env)  # 处理生命的重置
    if "FIRE" in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)  # 如果需要，重置环境以触发“FIRE”动作
    env = gym.wrappers.ResizeObservation(env, (84, 84))  # 调整观察的大小
    env = gym.wrappers.GrayScaleObservation(env)  # 转换为灰度图像
    env = NormalizeObservation(env)  # 归一化观察
    env = gym.wrappers.FrameStack(env, 4)  # 堆叠4帧作为观察
    env = ScaleReward(env, gamma=gamma)  # 归一化奖励

    # 初始化智能体
    agent = StreamQ(
        n_actions=env.action_space.n,  # 智能体可以选择的动作数量
        lr=lr,                           # 学习率，控制智能体学习的速度
        gamma=gamma,                     # 折扣因子，决定未来奖励的重要性
        lamda=lamda,                     # 用于优势估计的参数
        epsilon_target=epsilon_target,   # 目标 epsilon 值，训练后期的探索概率
        epsilon_start=epsilon_start,     # 初始 epsilon 值，训练开始时的探索概率
        exploration_fraction=exploration_fraction,  # 探索比例，控制 epsilon 衰减
        total_steps=total_steps,         # 总训练步数
        kappa_value=kappa_value          # 调节探索和利用之间平衡的参数
    )


    # 如果需要渲染，设置虚拟显示
    if render:
        ...
        # from pyvirtualdisplay import Display
        # virtual_display = Display(visible=0, size=(320, 240))
        # virtual_display.start()

    # 加载已有的智能体参数和统计数据
    if load_agent is not None:
        agent.load_state_dict(torch.load(load_agent+"/seed_{}.pth".format(seed), weights_only=False))
        reward_stats, obs_stats = pickle.load(open(load_agent+"/stats_data_{}.pkl".format(seed), "rb"))
        env.obs_stats.mean = obs_stats.mean
        env.obs_stats.var = obs_stats.var
        env.obs_stats.count = obs_stats.count
        env.obs_stats.p = obs_stats.p
        env.reward_stats.mean = reward_stats.mean
        env.reward_stats.var = reward_stats.var
        env.reward_stats.count = reward_stats.count
        env.reward_stats.p = reward_stats.p

    # 输出调试信息
    if debug:
        print("seed: {}".format(seed), "env: {}".format(env.spec.id))

    returns, term_time_steps, frames = [], [], []  # 用于存储回报、终止时间步和帧
    s, _ = env.reset(seed=seed)  # 重置环境并获取初始状态
    episode_num = 1  # 初始化回合计数器

    # 主训练循环
    for t in range(1, total_steps + 1):
        a, is_nongreedy = agent.sample_action(s)  # 从智能体中采样动作
        s_prime, r, terminated, _, info = env.step(a)  # 执行动作并获取反馈

        # 更新智能体参数
        if update_agent:
            agent.update_params(s, a, r, s_prime, terminated, is_nongreedy)

        s = s_prime  # 更新状态

        # 如果需要渲染，记录帧
        if render:
            if t % 1 == 0:
                frame = env.render()
                frames.append(frame)

        # 检查是否结束回合
        if info and "episode" in info:
            if debug:
                print("Episodic Return: {}, Time Step {}, Episode Number {}, Epsilon {}".format(info['episode']['r'][0], t, episode_num, agent.epsilon))
            returns.append(info['episode']['r'][0])  # 记录回报
            term_time_steps.append(t)  # 记录终止时间步
            s, _ = env.reset()  # 重置环境
            episode_num += 1  # 增加回合计数

    env.close()  # 关闭环境

    # 保存智能体和统计数据
    if save_agent:
        save_dir = "data_stream_q_{}".format(env.spec.id)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        with open(os.path.join(save_dir, "seed_{}.pkl".format(seed)), "wb") as f:
            pickle.dump((returns, term_time_steps, env_name), f)
        save_dir = "stream_q_{}".format(env.spec.id)
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        torch.save(agent.state_dict(), os.path.join(save_dir, "seed_{}.pth".format(seed)))
        reward_stats = env.reward_stats
        obs_stats = env.obs_stats
        with open(os.path.join(save_dir, "stats_data_{}.pkl".format(seed)), "wb") as f:
            pickle.dump((reward_stats, obs_stats), f)

    return frames  # 返回记录的帧

# %% [markdown]
# ### 8. Set hyperparameters and start the interaction

# %%
agent_env_interaction(env_name='PongNoFrameskip-v4',
                      seed=0,
                      lr=1.0,
                      gamma=0.99,
                      lamda=0.8,
                      total_steps=3_000_000,
                      epsilon_target=0.01,
                      epsilon_start=0.01,
                      exploration_fraction=0.05,
                      kappa_value=2.0,
                      debug=True,
                      save_agent=True,
                      update_agent=True,
                      load_agent="stream_q_PongNoFrameskip-v4",
                    #   render=True
)
# Out:
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# seed: 0 env: PongNoFrameskip-v4
# Episodic Return: -1.0, Time Step 3496, Episode Number 1, Epsilon 0.01
# Episodic Return: -5.0, Time Step 7758, Episode Number 2, Epsilon 0.01
# Episodic Return: -1.0, Time Step 11338, Episode Number 3, Epsilon 0.01
# Episodic Return: -1.0, Time Step 14684, Episode Number 4, Epsilon 0.01
# Episodic Return: 11.0, Time Step 17698, Episode Number 5, Epsilon 0.01
# Episodic Return: -1.0, Time Step 21540, Episode Number 6, Epsilon 0.01
# Episodic Return: -8.0, Time Step 25311, Episode Number 7, Epsilon 0.01
# Episodic Return: -4.0, Time Step 29112, Episode Number 8, Epsilon 0.01
# Episodic Return: -2.0, Time Step 33511, Episode Number 9, Epsilon 0.01
# Episodic Return: -1.0, Time Step 37082, Episode Number 10, Epsilon 0.01
# Episodic Return: -1.0, Time Step 40325, Episode Number 11, Epsilon 0.01
# Episodic Return: -1.0, Time Step 44548, Episode Number 12, Epsilon 0.01
# Episodic Return: -2.0, Time Step 49061, Episode Number 13, Epsilon 0.01
# Episodic Return: -16.0, Time Step 51546, Episode Number 14, Epsilon 0.01
# Episodic Return: -12.0, Time Step 53618, Episode Number 15, Epsilon 0.01
# Episodic Return: -2.0, Time Step 57440, Episode Number 16, Epsilon 0.01
# Episodic Return: -1.0, Time Step 61116, Episode Number 17, Epsilon 0.01
# Episodic Return: -1.0, Time Step 64931, Episode Number 18, Epsilon 0.01
# Episodic Return: -17.0, Time Step 67766, Episode Number 19, Epsilon 0.01
# Episodic Return: -1.0, Time Step 72563, Episode Number 20, Epsilon 0.01
# Episodic Return: -1.0, Time Step 75963, Episode Number 21, Epsilon 0.01
# Episodic Return: -1.0, Time Step 79870, Episode Number 22, Epsilon 0.01
# Episodic Return: -2.0, Time Step 83738, Episode Number 23, Epsilon 0.01
# Episodic Return: -14.0, Time Step 85357, Episode Number 24, Epsilon 0.01
# Episodic Return: -11.0, Time Step 87983, Episode Number 25, Epsilon 0.01
# Episodic Return: -4.0, Time Step 91991, Episode Number 26, Epsilon 0.01
# Episodic Return: -7.0, Time Step 95367, Episode Number 27, Epsilon 0.01
# Episodic Return: -1.0, Time Step 99411, Episode Number 28, Epsilon 0.01
# Episodic Return: 2.0, Time Step 103439, Episode Number 29, Epsilon 0.01
# Episodic Return: -9.0, Time Step 107020, Episode Number 30, Epsilon 0.01
# Episodic Return: -6.0, Time Step 111293, Episode Number 31, Epsilon 0.01
# Episodic Return: -5.0, Time Step 115616, Episode Number 32, Epsilon 0.01
# Episodic Return: -4.0, Time Step 119815, Episode Number 33, Epsilon 0.01
# Episodic Return: -1.0, Time Step 123804, Episode Number 34, Epsilon 0.01
# Episodic Return: -2.0, Time Step 128312, Episode Number 35, Epsilon 0.01
# Episodic Return: -1.0, Time Step 132123, Episode Number 36, Epsilon 0.01
# Episodic Return: -3.0, Time Step 135991, Episode Number 37, Epsilon 0.01
# Episodic Return: -1.0, Time Step 140154, Episode Number 38, Epsilon 0.01
# Episodic Return: 5.0, Time Step 143912, Episode Number 39, Epsilon 0.01
# Episodic Return: -5.0, Time Step 147945, Episode Number 40, Epsilon 0.01
# Episodic Return: -1.0, Time Step 151976, Episode Number 41, Epsilon 0.01
# Episodic Return: 2.0, Time Step 155349, Episode Number 42, Epsilon 0.01
# Episodic Return: -1.0, Time Step 159626, Episode Number 43, Epsilon 0.01
# Episodic Return: -1.0, Time Step 163555, Episode Number 44, Epsilon 0.01
# Episodic Return: -1.0, Time Step 167531, Episode Number 45, Epsilon 0.01
# Episodic Return: -3.0, Time Step 171877, Episode Number 46, Epsilon 0.01
# Episodic Return: -1.0, Time Step 174992, Episode Number 47, Epsilon 0.01
# Episodic Return: -1.0, Time Step 178593, Episode Number 48, Epsilon 0.01
# Episodic Return: -8.0, Time Step 181469, Episode Number 49, Epsilon 0.01
# Episodic Return: -1.0, Time Step 185629, Episode Number 50, Epsilon 0.01
# Episodic Return: -1.0, Time Step 189354, Episode Number 51, Epsilon 0.01
# Episodic Return: -1.0, Time Step 193122, Episode Number 52, Epsilon 0.01
# Episodic Return: 3.0, Time Step 196799, Episode Number 53, Epsilon 0.01
# Episodic Return: -8.0, Time Step 200050, Episode Number 54, Epsilon 0.01
# Episodic Return: -10.0, Time Step 203286, Episode Number 55, Epsilon 0.01
# Episodic Return: -9.0, Time Step 206848, Episode Number 56, Epsilon 0.01
# Episodic Return: -1.0, Time Step 210682, Episode Number 57, Epsilon 0.01
# Episodic Return: 2.0, Time Step 214394, Episode Number 58, Epsilon 0.01
# Episodic Return: 6.0, Time Step 217998, Episode Number 59, Epsilon 0.01
# Episodic Return: 3.0, Time Step 221848, Episode Number 60, Epsilon 0.01
# Episodic Return: -1.0, Time Step 226043, Episode Number 61, Epsilon 0.01
# Episodic Return: -1.0, Time Step 230131, Episode Number 62, Epsilon 0.01
# Episodic Return: -8.0, Time Step 234463, Episode Number 63, Epsilon 0.01
# Episodic Return: -13.0, Time Step 237887, Episode Number 64, Epsilon 0.01
# Episodic Return: -10.0, Time Step 241186, Episode Number 65, Epsilon 0.01
# Episodic Return: -12.0, Time Step 244789, Episode Number 66, Epsilon 0.01
# Episodic Return: -1.0, Time Step 248966, Episode Number 67, Epsilon 0.01
# Episodic Return: -1.0, Time Step 252834, Episode Number 68, Epsilon 0.01
# Episodic Return: -7.0, Time Step 257418, Episode Number 69, Epsilon 0.01
# Episodic Return: -1.0, Time Step 261098, Episode Number 70, Epsilon 0.01
# Episodic Return: -4.0, Time Step 265600, Episode Number 71, Epsilon 0.01
# Episodic Return: -1.0, Time Step 269401, Episode Number 72, Epsilon 0.01
# Episodic Return: -1.0, Time Step 273205, Episode Number 73, Epsilon 0.01
# Episodic Return: 2.0, Time Step 276264, Episode Number 74, Epsilon 0.01
# Episodic Return: -1.0, Time Step 280287, Episode Number 75, Epsilon 0.01
# Episodic Return: -1.0, Time Step 283851, Episode Number 76, Epsilon 0.01
# Episodic Return: -3.0, Time Step 288095, Episode Number 77, Epsilon 0.01
# Episodic Return: -4.0, Time Step 291892, Episode Number 78, Epsilon 0.01
# Episodic Return: -1.0, Time Step 296097, Episode Number 79, Epsilon 0.01
# Episodic Return: -5.0, Time Step 299970, Episode Number 80, Epsilon 0.01
# []

# %% [markdown]
# ### 9. Plot the learning curve

# %%
import numpy as np
import pickle, os
import matplotlib.pyplot as plt

def avg_return_curve(x, y, stride, total_steps):
    assert len(x) == len(y)
    num_runs = len(x)
    avg_ret = np.zeros(total_steps // stride)
    stderr_ret = np.zeros(total_steps // stride)
    avg_ret2 = np.zeros(total_steps // stride)
    stderr_ret2 = np.zeros(total_steps // stride)
    steps = np.arange(stride, total_steps + stride, stride)
    num_rets = np.zeros(total_steps // stride)
    individ_avg_rets_per_run = []
    for i in range(0, total_steps // stride):
        rets = []
        avg_rets_per_run = []
        for run in range(num_runs):
            xa = np.array(x[run])
            ya = np.array(y[run])
            rets.append(ya[np.logical_and(i * stride < xa, xa <= (i + 1) * stride)].tolist())
            avg_rets_per_run.append(np.mean(rets[-1]))
        individ_avg_rets_per_run.append(avg_rets_per_run)
        flat_rets = np.array([ret for l in rets for ret in l])
        num_rets[i] = flat_rets.shape[0]
        avg_ret[i] = flat_rets.mean()
        stderr_ret[i] = flat_rets.std() / np.sqrt(num_rets[i])
        avg_ret2[i] = np.mean(avg_rets_per_run)
        stderr_ret2[i] = np.std(avg_rets_per_run) / np.sqrt(num_runs)
    return steps, avg_ret, stderr_ret, num_rets, avg_ret2, stderr_ret2, individ_avg_rets_per_run

def plot(data_dir, int_space, total_steps):
    plt.figure(figsize=(8, 5))
    all_termination_time_steps, all_episodic_returns, env_name = [], [], ''
    for file in os.listdir(data_dir):
        if file.endswith(".pkl"):
            with open(os.path.join(data_dir, file), "rb") as f:
                episodic_returns, termination_time_steps, env_name = pickle.load(f)
                all_termination_time_steps.append(termination_time_steps)
                all_episodic_returns.append(episodic_returns)

    (
        steps,
        avg_ret,
        stderr_ret,
        num_rets,
        avg_ret2,
        stderr_ret2,
        individ_avg_rets_per_run,
    ) = avg_return_curve(all_termination_time_steps, all_episodic_returns, int_space, total_steps)

    plt.plot(steps, avg_ret2, linewidth=2.0)
    plt.fill_between(steps, avg_ret2 - stderr_ret2, avg_ret2 + stderr_ret2, alpha=0.4)

    plt.xlabel("Time Step", fontsize=14)
    plt.ylabel(f"Average Episodic Return", fontsize=14)
    plt.title(r"Stream Q(0.8) on Pong")
    plt.show()

plot(data_dir='data_stream_q_PongNoFrameskip-v4', int_space=100_000, total_steps=3_000_000)
# Out:
# C:\Users\andao\AppData\Local\Temp\ipykernel_9308\1565194741.py:26: RuntimeWarning: Mean of empty slice.
#   avg_ret[i] = flat_rets.mean()

# %% [markdown]
# ## 10. Load agents and continue the interaction

# %% [markdown]
# Let's save the actor and critic networks along with the observations mean/std and reward trace std. We also save the frames to visualize the behavior next.

# %%
frames = agent_env_interaction(env_name='PongNoFrameskip-v4',
                              seed=0,
                              lr=1.0,
                              gamma=0.99,
                              lamda=0.8,
                              total_steps=6000,
                              epsilon_target=0.01,
                              epsilon_start=0.01,
                              exploration_fraction=0.05,
                              kappa_value=2.0,
                              debug=True,
                              save_agent=False,
                              update_agent=False,
                              load_agent="stream_q_PongNoFrameskip-v4",
                              render=True)
# Out:
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\core.py:311: UserWarning: WARN: env.obs_stats to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.obs_stats` for environment variables or `env.get_wrapper_attr('obs_stats')` that will search the reminding wrappers.
#   logger.warn(
# seed: 0 env: PongNoFrameskip-v4
# c:\Users\andao\.conda\envs\drl\Lib\site-packages\gymnasium\utils\passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Episodic Return: -1.0, Time Step 4010, Episode Number 1, Epsilon 0.01

# %% [markdown]
# ### 10. See how the behavior looks like:

# %%
import imageio
# Save as a GIF
gif_path = 'PongNoFrameskip_v4.gif'
imageio.mimsave(gif_path, frames, format='GIF', fps=30)
# Display the GIF
from IPython.display import Image
Image(gif_path)
